# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numpy_perf = pd.read_csv("data/numpy-performance.csv")
pd_perf = pd.read_csv("data/pandas-performance.csv")

# %%
sns.lineplot(numpy_perf.index, numpy_perf.BuiltInCalculation, label="Numpy Built In")
ax = sns.lineplot(numpy_perf.index, numpy_perf.CustomCalculation, label="Numpy Custom")

# %%
sns.lineplot(pd_perf.index, pd_perf.BuiltInCalculation, label="Pandas Built In")
sns.lineplot(pd_perf.index, pd_perf.CustomCalculation, label="Pandas Custom")

# %%
sns.lineplot(numpy_perf.index, numpy_perf.Selection, label="Numpy")
sns.lineplot(pd_perf.index, pd_perf.Selection, label="Pandas")

# %%
sns.lineplot(numpy_perf.index, numpy_perf.BuiltInCalculation, label="Numpy")
sns.lineplot(pd_perf.index, pd_perf.BuiltInCalculation, label="Pandas")

# %%
sns.lineplot(numpy_perf.index, numpy_perf.CustomCalculation, label="Numpy")
sns.lineplot(pd_perf.index, pd_perf.CustomCalculation, label="Pandas")
